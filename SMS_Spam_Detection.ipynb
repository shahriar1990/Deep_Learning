# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriar1990/Deep_Learning/blob/main/SMS_Spam_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import os
import io
tf.__version__
# Out:
# '2.8.0'

# %% [markdown]
# In this chapter, we will focus on the basics of pre-processing text and
# build a simple spam detector. Speciﬁcally, we will learn about the
# following:
# * The typical text processing workﬂow
# * Data collection and labelingText
# * normalization, including case normalization, text
# * tokenization, stemming, and lemmatization
# * Modeling datasets that have been text normalized
# * Vectorizing text
# Modeling datasets with vectorized text

# %% [markdown]
# # Collecting labeled data
# In this book, we will rely on publicly available datasets. The
# appropriate datasets will be called out in their respective chapters
# along with instructions on downloading them. To build a spam
# detection system on an email dataset, we will be using the SMS
# Spam Collection dataset made available by University of California,
# Irvine. This dataset can be downloaded using instructions available
# in the tip box below. Each SMS is tagged as "SPAM" or "HAM," with
# the la er indicating it is not a spam message.

# %%
path_to_zip = tf.keras.utils.get_file("smsspamcollection.zip",
                  origin="https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip",
                  extract=True)

#unzip a file into the folder
# !unzip $path_to_zip -d data
# Out:
# Downloading data from https://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip
# 204800/203415 [==============================] - 0s 1us/step
# 212992/203415 [===============================] - 0s 1us/step
# Archive:  /root/.keras/datasets/smsspamcollection.zip
#   inflating: data/SMSSpamCollection
#   inflating: data/readme

# %%
lines = io.open('/content/data/SMSSpamCollection').read().strip().split('\n')
lines[5]
# Out:
# "spam\tFreeMsg Hey there darling it's been 3 week's now and no word back! I'd like some fun you up for it still? Tb ok! XxX std chgs to send, £1.50 to rcv"

# %% [markdown]
# # Preprocessing Data

# %%
spam_dataset = []
count = 0
for line in lines:
  label, text = line.split('\t')
  if label.lower().strip() == 'spam':
    spam_dataset.append((1, text.strip()))
    count += 1
  else:
    spam_dataset.append(((0, text.strip())))

print(spam_dataset[0])
print("Spam: ", count)
# Out:
# (0, 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...')
# Spam:  747

# %% [markdown]
# # Data Normalization

# %%
import pandas as pd

df = pd.DataFrame(spam_dataset,columns=['Spam','Message'])
df
# Out:
#       Spam                                            Message
# 0        0  Go until jurong point, crazy.. Available only ...
# 1        0                      Ok lar... Joking wif u oni...
# 2        1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3        0  U dun say so early hor... U c already then say...
# 4        0  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5569     1  This is the 2nd time we have tried 2 contact u...
# 5570     0               Will ü b going to esplanade fr home?
# 5571     0  Pity, * was in mood for that. So...any other s...
# 5572     0  The guy did some bitching but I acted like i'd...
# 5573     0                         Rofl. Its true to its name
#
# [5574 rows x 2 columns]

# %%
import re

#Normalization Functions

def message_length(x):
  # returns total number of characters
  return len(x)

def num_capitals(x):
  _,count = re.subn(r'[A-Z]','',x)
  return count

def num_punctutation(x):
  _,count = re.subn(r'[\W]','',x)
  return count

# %%
df['Capitals'] = df['Message'].apply(num_capitals)
df['punctutation'] = df['Message'].apply(num_punctuation)
df['Length'] = df['Message'].apply(message_length)

# %%
df.describe()
# Out:
#               Spam     Capitals  punctutation       Length
# count  5574.000000  5574.000000   5574.000000  5574.000000
# mean      0.134015     5.621636     18.942591    80.443488
# std       0.340699    11.683233     14.825994    59.841746
# min       0.000000     0.000000      0.000000     2.000000
# 25%       0.000000     1.000000      8.000000    36.000000
# 50%       0.000000     2.000000     15.000000    61.000000
# 75%       0.000000     4.000000     27.000000   122.000000
# max       1.000000   129.000000    253.000000   910.000000

# %%
train = df.sample(frac=0.8,random_state=42)
test = df.drop(train.index)

# %%
train.describe()
# Out:
#               Spam     Capitals  punctutation       Length
# count  4459.000000  4459.000000   4459.000000  4459.000000
# mean      0.132765     5.519399     18.886522    80.316439
# std       0.339359    11.405424     14.602023    59.346407
# min       0.000000     0.000000      0.000000     2.000000
# 25%       0.000000     1.000000      8.000000    35.000000
# 50%       0.000000     2.000000     15.000000    61.000000
# 75%       0.000000     4.000000     27.000000   122.000000
# max       1.000000   129.000000    253.000000   910.000000

# %%
test.describe()
# Out:
#               Spam     Capitals  punctutation       Length
# count  1115.000000  1115.000000   1115.000000  1115.000000
# mean      0.139013     6.030493     19.166816    80.951570
# std       0.346116    12.731059     15.694599    61.807655
# min       0.000000     0.000000      0.000000     2.000000
# 25%       0.000000     1.000000      8.000000    36.000000
# 50%       0.000000     2.000000     15.000000    61.000000
# 75%       0.000000     4.000000     28.000000   123.000000
# max       1.000000   127.000000    195.000000   790.000000

# %% [markdown]
# # Model Building

# %%
def make_model(input_dims=3, num_units=12):
  model = tf.keras.Sequential()

  # Adds a densely-connected layer with 12 units to the model:
  model.add(tf.keras.layers.Dense(num_units, 
                                  input_dim=input_dims, 
                                  activation='relu'))

  # Add a sigmoid layer with a binary output unit:
  model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', 
                metrics=['accuracy'])
  return model

# %%
x_train = train[['Length','punctutation','Capitals']]
y_train = train['Spam']

x_test = test[['Length','punctutation','Capitals']]
y_test = test['Spam']

# %%
x_train
# Out:
#       Length  punctutation  Capitals
# 3690      25             4         1
# 3527     161            48       107
# 724       40             7         1
# 3370      69            17         3
# 468       37             8         1
# ...      ...           ...       ...
# 3280     444           114        44
# 3186      65            14        50
# 3953      81            23         2
# 2768      38             8         2
# 4223      65            14         2
#
# [4459 rows x 3 columns]

# %%
model = make_model()

# %%
model.fit(x_train,y_train,epochs=10,batch_size=10)
# Out:
# Epoch 1/10
# 446/446 [==============================] - 2s 2ms/step - loss: 0.7134 - accuracy: 0.8471
# Epoch 2/10
# 446/446 [==============================] - 1s 2ms/step - loss: 0.3961 - accuracy: 0.8737
# Epoch 3/10
# 446/446 [==============================] - 1s 2ms/step - loss: 0.3431 - accuracy: 0.8780
# Epoch 4/10
# 446/446 [==============================] - 1s 3ms/step - loss: 0.3014 - accuracy: 0.8867
# Epoch 5/10
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2912 - accuracy: 0.8921
# Epoch 6/10
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2818 - accuracy: 0.8876
# Epoch 7/10
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2887 - accuracy: 0.8941
# Epoch 8/10
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2780 - accuracy: 0.8955
# Epoch 9/10
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2759 - accuracy: 0.8894
# Epoch 10/10
# 446/446 [==============================] - 1s 1ms/step - loss: 0.2810 - accuracy: 0.8901

# %%
model.evaluate(x_test,y_test)
# Out:
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3028 - accuracy: 0.8700
# [0.3027591109275818, 0.8699551820755005]

# %%
y_train_pred = model.predict(x_train)
# Out:
# array([[0.04612938],
#        [0.15152553],
#        [0.05732074],
#        ...,
#        [0.01037714],
#        [0.03827438],
#        [0.04750213]], dtype=float32)

# %% [markdown]
# #Tokenization and Stop Word Removal

# %%
sentence = 'Go until jurong point, crazy.. Available only in bugis n great world'
sentence.split()
# Out:
# ['Go',
#  'until',
#  'jurong',
#  'point,',
#  'crazy..',
#  'Available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world']

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.3.0-py3-none-any.whl (432 kB)
#      |████████████████████████████████| 432 kB 5.2 MB/s
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.10.0+cu111)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.63.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.17.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.21.5)
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 66.3 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from stanza) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.10.0.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=a9ec836b891123c4d7cf3bd54860acd40060e7f827336f8a20319b0b9bbc74ab
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji, stanza
# Successfully installed emoji-1.7.0 stanza-1.3.0

# %%
import stanza

# %%
en = stanza.download('en')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-04-04 05:51:28 INFO: Downloading default packages for language: en (English)...
# Downloading https://huggingface.co/stanfordnlp/stanza-en/resolve/v1.3.0/models/default.zip:   0%|          | 0…
# 2022-04-04 05:51:39 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
en = stanza.Pipeline(lang='en')
# Out:
# 2022-04-04 05:52:26 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-04-04 05:52:26 INFO: Use device: cpu
# 2022-04-04 05:52:26 INFO: Loading: tokenize
# 2022-04-04 05:52:27 INFO: Loading: pos
# 2022-04-04 05:52:27 INFO: Loading: lemma
# 2022-04-04 05:52:27 INFO: Loading: depparse
# 2022-04-04 05:52:27 INFO: Loading: sentiment
# 2022-04-04 05:52:28 INFO: Loading: constituency
# 2022-04-04 05:52:29 INFO: Loading: ner
# 2022-04-04 05:52:30 INFO: Done loading processors!

# %%
sentence
# Out:
# 'Go until jurong point, crazy.. Available only in bugis n great world'

# %%
tokenized = en(sentence)

# %%
len(tokenized.sentences)
# Out:
# 2

# %%
for snt in tokenized.sentences:
  for word in snt.tokens:
    print(word.text)
  print("<End of Sentence>")
# Out:
# Go
# until
# jurong
# point
# ,
# crazy
# ..
# <End of Sentence>
# Available
# only
# in
# bugis
# n
# great
# world
# <End of Sentence>

# %% [markdown]
# # Dependency Parsing Example

# %%
en2 = stanza.Pipeline(lang='en')
pr2 = en2('Hari went to school')
for snt in pr2.sentences:
  for word in snt.tokens:
    print(word)
# Out:
# 2022-04-04 06:06:07 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-04-04 06:06:07 INFO: Use device: cpu
# 2022-04-04 06:06:07 INFO: Loading: tokenize
# 2022-04-04 06:06:07 INFO: Loading: pos
# 2022-04-04 06:06:08 INFO: Loading: lemma
# 2022-04-04 06:06:08 INFO: Loading: depparse
# 2022-04-04 06:06:09 INFO: Loading: sentiment
# 2022-04-04 06:06:10 INFO: Loading: constituency
# 2022-04-04 06:06:11 INFO: Loading: ner
# 2022-04-04 06:06:12 INFO: Done loading processors!
# [
#   {
#     "id": 1,
#     "text": "Hari",
#     "lemma": "Hari",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 2,
#     "deprel": "nsubj",
#     "start_char": 0,
#     "end_char": 4,
#     "ner": "S-PERSON"
#   }
# ]
# [
#   {
#     "id": 2,
#     "text": "went",
#     "lemma": "go",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 5,
#     "end_char": 9,
#     "ner": "O"
#   }
# ]
# [
#   {
#     "id": 3,
#     "text": "to",
#     "lemma": "to",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 4,
#     "deprel": "case",
#     "start_char": 10,
#     "end_char": 12,
#     "ner": "O"
#   }
# ]
# [
#   {
#     "id": 4,
#     "text": "school",
#     "lemma": "school",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 2,
#     "deprel": "obl",
#     "start_char": 13,
#     "end_char": 19,
#     "ner": "O"
#   }
# ]

# %%
fa = stanza.download('fa')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.3.0.json:   0%|   …
# 2022-04-04 06:09:10 INFO: Downloading default packages for language: fa (Persian)...
# Downloading https://huggingface.co/stanfordnlp/stanza-fa/resolve/v1.3.0/models/default.zip:   0%|          | 0…
# 2022-04-04 06:09:19 INFO: Finished downloading models and saved to /root/stanza_resources.

# %%
fa = stanza.Pipeline(lang='fa')
# Out:
# 2022-04-04 06:10:07 INFO: Loading these models for language: fa (Persian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | perdt   |
# | mwt       | perdt   |
# | pos       | perdt   |
# | lemma     | perdt   |
# | depparse  | perdt   |
# =======================
#
# 2022-04-04 06:10:07 INFO: Use device: cpu
# 2022-04-04 06:10:07 INFO: Loading: tokenize
# 2022-04-04 06:10:07 INFO: Loading: mwt
# 2022-04-04 06:10:07 INFO: Loading: pos
# 2022-04-04 06:10:08 INFO: Loading: lemma
# 2022-04-04 06:10:08 INFO: Loading: depparse
# 2022-04-04 06:10:09 INFO: Done loading processors!

# %%
fa_line = fa('نگامی که عبارتی را در ترجمه‌گری مثل گوگل ترنسلیت تایپ می‌کنید یا با ویرایشگرهای متنی (مثل مایکروسافت ورد) کار می‌کنید در حقیقت بخشی از فرایند تصحیح و پیشنهاد عبارات توسط NLP انجام می‌شود، ضمنا رایانه‌های امروزی قادرند خلاصه‌ای از یک متن طولانی را در اختیار کاربران قرار دهند!')

# %%
for snt in fa_line.sentences:
  for word in snt.tokens:
    print(word.text)
# Out:
# نگامی
# که
# عبارتی
# را
# در
# ترجمه‌گری
# مثل
# گوگل
# ترنسلیت
# تایپ
# می‌کنید
# یا
# با
# ویرایشگرهای
# متنی
# (
# مثل
# مایکروسافت
# ورد
# )
# کار
# می‌کنید
# در
# حقیقت
# بخشی
# از
# فرایند
# تصحیح
# و
# پیشنهاد
# عبارات
# توسط
# NLP
# انجام
# می‌شود
# ،
# ضمنا
# رایانه‌های
# امروزی
# قادرند
# خلاصه‌ای
# از
# یک
# متن
# طولانی
# را
# در
# اختیار
# کاربران
# قرار
# دهند
# !

# %%
fa = stanza.Pipeline(lang='fa')
pr2 = fa('نگامی که عبارتی را در ترجمه‌گری مثل گوگل ترنسلیت تایپ می‌کنید یا با ویرایشگرهای متنی (مثل مایکروسافت ورد) کار می‌کنید در حقیقت بخشی از فرایند تصحیح و پیشنهاد عبارات توسط NLP انجام می‌شود، ضمنا رایانه‌های امروزی قادرند خلاصه‌ای از یک متن طولانی را در اختیار کاربران قرار دهند!')
for snt in pr2.sentences:
  for word in snt.tokens:
    print(word)
# Out:
# 2022-04-04 06:54:38 INFO: Loading these models for language: fa (Persian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | perdt   |
# | mwt       | perdt   |
# | pos       | perdt   |
# | lemma     | perdt   |
# | depparse  | perdt   |
# =======================
#
# 2022-04-04 06:54:38 INFO: Use device: cpu
# 2022-04-04 06:54:38 INFO: Loading: tokenize
# 2022-04-04 06:54:38 INFO: Loading: mwt
# 2022-04-04 06:54:38 INFO: Loading: pos
# 2022-04-04 06:54:38 INFO: Loading: lemma
# 2022-04-04 06:54:38 INFO: Loading: depparse
# 2022-04-04 06:54:39 INFO: Done loading processors!
# [
#   {
#     "id": 1,
#     "text": "نگامی",
#     "lemma": "نگط",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 35,
#     "deprel": "nsubj",
#     "start_char": 0,
#     "end_char": 5
#   }
# ]
# [
#   {
#     "id": 2,
#     "text": "که",
#     "lemma": "که",
#     "upos": "SCONJ",
#     "xpos": "SUBR",
#     "head": 1,
#     "deprel": "acl",
#     "start_char": 6,
#     "end_char": 8
#   }
# ]
# [
#   {
#     "id": 3,
#     "text": "عبارتی",
#     "lemma": "عبارت",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 11,
#     "deprel": "obj",
#     "start_char": 9,
#     "end_char": 15
#   }
# ]
# [
#   {
#     "id": 4,
#     "text": "را",
#     "lemma": "را",
#     "upos": "ADP",
#     "xpos": "POSTP",
#     "head": 3,
#     "deprel": "case",
#     "start_char": 16,
#     "end_char": 18
#   }
# ]
# [
#   {
#     "id": 5,
#     "text": "در",
#     "lemma": "در",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 6,
#     "deprel": "case",
#     "start_char": 19,
#     "end_char": 21
#   }
# ]
# [
#   {
#     "id": 6,
#     "text": "ترجمه‌گری",
#     "lemma": "ترجمه‌گری",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 11,
#     "deprel": "obl",
#     "start_char": 22,
#     "end_char": 31
#   }
# ]
# [
#   {
#     "id": 7,
#     "text": "مثل",
#     "lemma": "مثل",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 8,
#     "deprel": "case",
#     "start_char": 32,
#     "end_char": 35
#   }
# ]
# [
#   {
#     "id": 8,
#     "text": "گوگل",
#     "lemma": "گوگل",
#     "upos": "PROPN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 6,
#     "deprel": "nmod",
#     "start_char": 36,
#     "end_char": 40
#   }
# ]
# [
#   {
#     "id": 9,
#     "text": "ترنسلیت",
#     "lemma": "ترنسلیت",
#     "upos": "PROPN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 8,
#     "deprel": "flat:name",
#     "start_char": 41,
#     "end_char": 48
#   }
# ]
# [
#   {
#     "id": 10,
#     "text": "تایپ",
#     "lemma": "تایپ",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 11,
#     "deprel": "compound:lvc",
#     "start_char": 49,
#     "end_char": 53
#   }
# ]
# [
#   {
#     "id": 11,
#     "text": "می‌کنید",
#     "lemma": "کرد#کن",
#     "upos": "VERB",
#     "xpos": "V_ACT",
#     "feats": "Number=Plur|Person=2|Tense=Pres|Voice=Act",
#     "head": 2,
#     "deprel": "acl",
#     "start_char": 54,
#     "end_char": 61
#   }
# ]
# [
#   {
#     "id": 12,
#     "text": "یا",
#     "lemma": "یا",
#     "upos": "CCONJ",
#     "xpos": "CONJ",
#     "head": 22,
#     "deprel": "cc",
#     "start_char": 62,
#     "end_char": 64
#   }
# ]
# [
#   {
#     "id": 13,
#     "text": "با",
#     "lemma": "با",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 14,
#     "deprel": "case",
#     "start_char": 65,
#     "end_char": 67
#   }
# ]
# [
#   {
#     "id": 14,
#     "text": "ویرایشگرهای",
#     "lemma": "ویرایشگر",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Plur",
#     "head": 22,
#     "deprel": "obl",
#     "start_char": 68,
#     "end_char": 79
#   }
# ]
# [
#   {
#     "id": 15,
#     "text": "متنی",
#     "lemma": "متنی",
#     "upos": "ADJ",
#     "xpos": "ADJ_AJP",
#     "head": 14,
#     "deprel": "amod",
#     "start_char": 80,
#     "end_char": 84
#   }
# ]
# [
#   {
#     "id": 16,
#     "text": "(",
#     "lemma": "(",
#     "upos": "PUNCT",
#     "xpos": "PUNC",
#     "head": 18,
#     "deprel": "punct",
#     "start_char": 85,
#     "end_char": 86
#   }
# ]
# [
#   {
#     "id": 17,
#     "text": "مثل",
#     "lemma": "مثل",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 18,
#     "deprel": "case",
#     "start_char": 86,
#     "end_char": 89
#   }
# ]
# [
#   {
#     "id": 18,
#     "text": "مایکروسافت",
#     "lemma": "مایکروسافت",
#     "upos": "PROPN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 14,
#     "deprel": "nmod",
#     "start_char": 90,
#     "end_char": 100
#   }
# ]
# [
#   {
#     "id": 19,
#     "text": "ورد",
#     "lemma": "ورد",
#     "upos": "PROPN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 18,
#     "deprel": "flat:name",
#     "start_char": 101,
#     "end_char": 104
#   }
# ]
# [
#   {
#     "id": 20,
#     "text": ")",
#     "lemma": ")",
#     "upos": "PUNCT",
#     "xpos": "PUNC",
#     "head": 18,
#     "deprel": "punct",
#     "start_char": 104,
#     "end_char": 105
#   }
# ]
# [
#   {
#     "id": 21,
#     "text": "کار",
#     "lemma": "کار",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 22,
#     "deprel": "compound:lvc",
#     "start_char": 106,
#     "end_char": 109
#   }
# ]
# [
#   {
#     "id": 22,
#     "text": "می‌کنید",
#     "lemma": "کرد#کن",
#     "upos": "VERB",
#     "xpos": "V_ACT",
#     "feats": "Number=Plur|Person=2|Tense=Pres|Voice=Act",
#     "head": 11,
#     "deprel": "conj",
#     "start_char": 110,
#     "end_char": 117
#   }
# ]
# [
#   {
#     "id": 23,
#     "text": "در",
#     "lemma": "در",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 24,
#     "deprel": "case",
#     "start_char": 118,
#     "end_char": 120
#   }
# ]
# [
#   {
#     "id": 24,
#     "text": "حقیقت",
#     "lemma": "حقیقت",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 35,
#     "deprel": "obl",
#     "start_char": 121,
#     "end_char": 126
#   }
# ]
# [
#   {
#     "id": 25,
#     "text": "بخشی",
#     "lemma": "بخش",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 35,
#     "deprel": "nsubj",
#     "start_char": 127,
#     "end_char": 131
#   }
# ]
# [
#   {
#     "id": 26,
#     "text": "از",
#     "lemma": "از",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 27,
#     "deprel": "case",
#     "start_char": 132,
#     "end_char": 134
#   }
# ]
# [
#   {
#     "id": 27,
#     "text": "فرایند",
#     "lemma": "فرایند",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 25,
#     "deprel": "nmod",
#     "start_char": 135,
#     "end_char": 141
#   }
# ]
# [
#   {
#     "id": 28,
#     "text": "تصحیح",
#     "lemma": "تصحیح",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 27,
#     "deprel": "nmod",
#     "start_char": 142,
#     "end_char": 147
#   }
# ]
# [
#   {
#     "id": 29,
#     "text": "و",
#     "lemma": "و",
#     "upos": "CCONJ",
#     "xpos": "CONJ",
#     "head": 30,
#     "deprel": "cc",
#     "start_char": 148,
#     "end_char": 149
#   }
# ]
# [
#   {
#     "id": 30,
#     "text": "پیشنهاد",
#     "lemma": "پیشنهاد",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 28,
#     "deprel": "conj",
#     "start_char": 150,
#     "end_char": 157
#   }
# ]
# [
#   {
#     "id": 31,
#     "text": "عبارات",
#     "lemma": "عبارت",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Plur",
#     "head": 30,
#     "deprel": "nmod",
#     "start_char": 158,
#     "end_char": 164
#   }
# ]
# [
#   {
#     "id": 32,
#     "text": "توسط",
#     "lemma": "توسط",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 33,
#     "deprel": "case",
#     "start_char": 165,
#     "end_char": 169
#   }
# ]
# [
#   {
#     "id": 33,
#     "text": "NLP",
#     "lemma": "NLP",
#     "upos": "PROPN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 28,
#     "deprel": "nmod",
#     "start_char": 170,
#     "end_char": 173
#   }
# ]
# [
#   {
#     "id": 34,
#     "text": "انجام",
#     "lemma": "انجام",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 35,
#     "deprel": "compound:lvc",
#     "start_char": 174,
#     "end_char": 179
#   }
# ]
# [
#   {
#     "id": 35,
#     "text": "می‌شود",
#     "lemma": "شد#شو",
#     "upos": "VERB",
#     "xpos": "V_PASS",
#     "feats": "Number=Sing|Person=3|Tense=Pres|Voice=Pass",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 180,
#     "end_char": 186
#   }
# ]
# [
#   {
#     "id": 36,
#     "text": "،",
#     "lemma": "،",
#     "upos": "PUNCT",
#     "xpos": "PUNC",
#     "head": 35,
#     "deprel": "punct",
#     "start_char": 186,
#     "end_char": 187
#   }
# ]
# [
#   {
#     "id": 37,
#     "text": "ضمنا",
#     "lemma": "ضمنا",
#     "upos": "ADV",
#     "xpos": "ADV_SADV",
#     "head": 51,
#     "deprel": "advmod",
#     "start_char": 188,
#     "end_char": 192
#   }
# ]
# [
#   {
#     "id": 38,
#     "text": "رایانه‌های",
#     "lemma": "رایانه",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Plur",
#     "head": 51,
#     "deprel": "nsubj",
#     "start_char": 193,
#     "end_char": 203
#   }
# ]
# [
#   {
#     "id": 39,
#     "text": "امروزی",
#     "lemma": "امروزی",
#     "upos": "ADJ",
#     "xpos": "ADJ_AJP",
#     "head": 38,
#     "deprel": "amod",
#     "start_char": 204,
#     "end_char": 210
#   }
# ]
# [
#   {
#     "id": 40,
#     "text": "قادرند",
#     "lemma": "قادرند",
#     "upos": "ADJ",
#     "xpos": "ADJ_AJP",
#     "head": 38,
#     "deprel": "amod",
#     "start_char": 211,
#     "end_char": 217
#   }
# ]
# [
#   {
#     "id": 41,
#     "text": "خلاصه‌ای",
#     "lemma": "خلاصه",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 51,
#     "deprel": "obj",
#     "start_char": 218,
#     "end_char": 226
#   }
# ]
# [
#   {
#     "id": 42,
#     "text": "از",
#     "lemma": "از",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 44,
#     "deprel": "case",
#     "start_char": 227,
#     "end_char": 229
#   }
# ]
# [
#   {
#     "id": 43,
#     "text": "یک",
#     "lemma": "یک",
#     "upos": "NUM",
#     "xpos": "PRENUM",
#     "head": 44,
#     "deprel": "nummod",
#     "start_char": 230,
#     "end_char": 232
#   }
# ]
# [
#   {
#     "id": 44,
#     "text": "متن",
#     "lemma": "متن",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 41,
#     "deprel": "nmod",
#     "start_char": 233,
#     "end_char": 236
#   }
# ]
# [
#   {
#     "id": 45,
#     "text": "طولانی",
#     "lemma": "طولانی",
#     "upos": "ADJ",
#     "xpos": "ADJ_AJP",
#     "head": 44,
#     "deprel": "amod",
#     "start_char": 237,
#     "end_char": 243
#   }
# ]
# [
#   {
#     "id": 46,
#     "text": "را",
#     "lemma": "را",
#     "upos": "ADP",
#     "xpos": "POSTP",
#     "head": 41,
#     "deprel": "case",
#     "start_char": 244,
#     "end_char": 246
#   }
# ]
# [
#   {
#     "id": 47,
#     "text": "در",
#     "lemma": "در",
#     "upos": "ADP",
#     "xpos": "PREP",
#     "head": 48,
#     "deprel": "case",
#     "start_char": 247,
#     "end_char": 249
#   }
# ]
# [
#   {
#     "id": 48,
#     "text": "اختیار",
#     "lemma": "اختیار",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 51,
#     "deprel": "obl:arg",
#     "start_char": 250,
#     "end_char": 256
#   }
# ]
# [
#   {
#     "id": 49,
#     "text": "کاربران",
#     "lemma": "کاربر",
#     "upos": "NOUN",
#     "xpos": "N_ANM",
#     "feats": "Number=Plur",
#     "head": 48,
#     "deprel": "nmod",
#     "start_char": 257,
#     "end_char": 264
#   }
# ]
# [
#   {
#     "id": 50,
#     "text": "قرار",
#     "lemma": "قرار",
#     "upos": "NOUN",
#     "xpos": "N_IANM",
#     "feats": "Number=Sing",
#     "head": 51,
#     "deprel": "compound:lvc",
#     "start_char": 265,
#     "end_char": 269
#   }
# ]
# [
#   {
#     "id": 51,
#     "text": "دهند",
#     "lemma": "داد#ده",
#     "upos": "VERB",
#     "xpos": "V_ACT",
#     "feats": "Number=Plur|Person=3|Voice=Act",
#     "head": 35,
#     "deprel": "conj",
#     "start_char": 270,
#     "end_char": 274
#   }
# ]
# [
#   {
#     "id": 52,
#     "text": "!",
#     "lemma": "!",
#     "upos": "PUNCT",
#     "xpos": "PUNC",
#     "head": 51,
#     "deprel": "punct",
#     "start_char": 274,
#     "end_char": 275
#   }
# ]

# %% [markdown]
# # Adding word count features

# %%
def word_counts(x, pipeline=en):
  doc = pipeline(x)
  count = sum( [ len(sentence.tokens) for sentence in doc.sentences] )
  return count

# %%
df['Words'] = df['Message'].apply(word_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/lstm_model.py in initial_word_queues(self, tagged_word_lists)
#     284                 try:
# --> 285                     tag_idx = torch.stack([self.tag_tensors[self.tag_map[word.label]] for word in tagged_words])
#     286                     tag_input = self.tag_embedding(tag_idx)
#
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/lstm_model.py in <listcomp>(.0)
#     284                 try:
# --> 285                     tag_idx = torch.stack([self.tag_tensors[self.tag_map[word.label]] for word in tagged_words])
#     286                     tag_input = self.tag_embedding(tag_idx)
#
# KeyError: 'GW'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-c7081786759d> in <module>()
# ----> 1 df['Words'] = df['Message'].apply(word_counts)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1099                     values,
#    1100                     f,  # type: ignore[arg-type]
# -> 1101                     convert=self.convert_dtype,
#    1102                 )
#    1103
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-87-a4c51dcb7709> in word_counts(x, pipeline)
#       1 def word_counts(x, pipeline=en):
# ----> 2   doc = pipeline(x)
#       3   count = sum( [ len(sentence.tokens) for sentence in doc.sentences] )
#       4   return count
#
# /usr/local/lib/python3.7/dist-packages/stanza/pipeline/core.py in __call__(self, doc)
#     229         assert any([isinstance(doc, str), isinstance(doc, list),
#     230                     isinstance(doc, Document)]), 'input should be either str, list or Document'
# --> 231         doc = self.process(doc)
#     232         return doc
#     233
#
# /usr/local/lib/python3.7/dist-packages/stanza/pipeline/core.py in process(self, doc)
#     223             if self.processors.get(processor_name):
#     224                 process = self.processors[processor_name].bulk_process if bulk else self.processors[processor_name].process
# --> 225                 doc = process(doc)
#     226         return doc
#     227
#
# /usr/local/lib/python3.7/dist-packages/stanza/pipeline/constituency_processor.py in process(self, document)
#      48         # TODO: maybe some constituency models are trained on UPOS not XPOS
#      49         words = [[(w.text, w.xpos) for w in s.words] for s in sentences]
# ---> 50         trees = trainer.parse_tagged_words(self._model.model, words, self._batch_size)
#      51         document.set(CONSTITUENCY, trees, to_sentence=True)
#      52         return document
#
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/trainer.py in parse_tagged_words(model, words, batch_size)
#     543
#     544     sentence_iterator = iter(words)
# --> 545     treebank = parse_sentences(sentence_iterator, build_batch_from_tagged_words, batch_size, model)
#     546
#     547     results = [t[1][0][0] for t in treebank]
#
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/trainer.py in parse_sentences(data_iterator, build_batch_fn, batch_size, model)
#     499     """
#     500     treebank = []
# --> 501     tree_batch = build_batch_fn(batch_size, data_iterator, model)
#     502     horizon_iterator = iter([])
#     503
#
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/trainer.py in build_batch_from_tagged_words(batch_size, data_iterator, model)
#     483
#     484     if len(tree_batch) > 0:
# --> 485         tree_batch = parse_transitions.initial_state_from_words(tree_batch, model)
#     486     return tree_batch
#     487
#
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/parse_transitions.py in initial_state_from_words(word_lists, model)
#     137             preterminals.append(tag_node)
#     138         preterminal_lists.append(preterminals)
# --> 139     return initial_state_from_preterminals(preterminal_lists, model, gold_trees=None)
#     140
#     141 def initial_state_from_gold_trees(trees, model):
#
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/parse_transitions.py in initial_state_from_preterminals(preterminal_lists, model, gold_trees)
#     110     what is passed in should be a list of list of preterminals
#     111     """
# --> 112     word_queues = model.initial_word_queues(preterminal_lists)
#     113     # this is the bottom of the TreeStack and will be the same for each State
#     114     transitions=model.initial_transitions()
#
# /usr/local/lib/python3.7/dist-packages/stanza/models/constituency/lstm_model.py in initial_word_queues(self, tagged_word_lists)
#     287                     word_inputs.append(tag_input)
#     288                 except KeyError as e:
# --> 289                     raise KeyError("Constituency parser not trained with tag {}".format(str(e))) from e
#     290
#     291             all_word_labels.append(word_labels)
#
# KeyError: "Constituency parser not trained with tag 'GW'"
